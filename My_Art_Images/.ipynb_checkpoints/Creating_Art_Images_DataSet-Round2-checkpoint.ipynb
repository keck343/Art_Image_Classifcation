# %% [markdown]
# # Classing Art Styles
#
# This is a fun data set to test to train a model can learn different art styles!
#
# Please note the following commands were run on an instance through google. The pip install torch_nightly will not install on my mac.

# %% [markdown]
# !pip install --upgrade pip
# !pip install torch_nightly -f https://download.pytorch.org/whl/nightly/cu92/torch_nightly.html
# !pip install fastai
# !pip install fastai --upgrade

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import warnings; warnings.simplefilter('ignore')  
# will throw warning: "Palette images with Transparency expressed in bytes should be converted to RGBA images"

# %%
from fastai import *
from fastai.vision import *

# %% [markdown]
# Run Each Cell Below to create folders from CSV's of image URLs.

# %%
folder = 'impressionisum'
file = 'Impressionisum.csv'
path = Path('artstyles')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)
download_images(path/file, dest, max_pics=600)
# Will throw errors for files that are two large

# %%
folder = 'realisum'
file = 'Realism.csv'
path = Path('artstyles')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)
download_images(path/file, dest, max_pics=600)

# %%
folder = 'pop_art'
file = 'pop_art.csv'
path = Path('artstyles')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)
download_images(path/file, dest, max_pics=600)

# %%
folder = 'splatter_paint'
file = 'splatter_paint.csv'
path = Path('artstyles')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)
download_images(path/file, dest, max_pics=600)

# %%
folder = 'cubisum'
file = 'cubisum.csv'
path = Path('artstyles')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)
download_images(path/file, dest, max_pics=600)

# %%
folder = 'minimalism'
file = 'Minimalism.csv'
path = Path('artstyles')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)
download_images(path/file, dest, max_pics=600)

# %% [markdown]
# Testing Data

# %%
path = Path('artstyles')
classes = ['minimalism','cubisum','realisum', 'splatter_paint', 'pop_art', 'impressionisum']

# %%
for c in classes:
    print(c)
    verify_images(path/c, delete=True, max_workers=8)
# Out:
# minimalism
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='298' class='' max='298', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [298/298 00:00<00:00]
#     </div>
# cubisum
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='454' class='' max='454', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [454/454 00:00<00:00]
#     </div>
# realisum
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='239' class='' max='239', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [239/239 00:00<00:00]
#     </div>
# splatter_paint
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='405' class='' max='405', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [405/405 00:00<00:00]
#     </div>
# pop_art
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='461' class='' max='461', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [461/461 00:00<00:00]
#     </div>
# impressionisum
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='146' class='' max='146', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [146/146 00:00<00:00]
#     </div>

# %%
np.random.seed(42)
path = Path('artstyles')
data = ImageDataBunch.from_folder(path, train=".", valid_pct=0.2, ds_tfms=get_transforms(), size=224, num_workers=4).normalize(imagenet_stats)

#padding_mode = 'zeros', or padding_mode = 'border', will make data NoneType

# %%
type(data)
# Out:
# fastai.vision.data.ImageDataBunch

# %%
data.classes
# Out:
# ['cubisum',
#  'impressionisum',
#  'minimalism',
#  'pop_art',
#  'realisum',
#  'splatter_paint']

# %%
data.c # number of classes
# Out:
# 6

# %%
data.show_batch(rows=3, figsize=(7,8))

# %% [markdown]
# **Train a Model**

# %%
learn = create_cnn(data, models.resnet34, metrics=accuracy)

# %%
learn.fit_one_cycle(1)
# Out:
# Total time: 00:40
# epoch  train_loss  valid_loss  accuracy
# 1      1.020171    0.462875    0.827103  (00:40)

# %%
learn.fit_one_cycle(1)
# Out:
# Total time: 00:30
# epoch  train_loss  valid_loss  accuracy
# 1      0.556075    0.429782    0.848131  (00:30)

# %%
learn.save('stage-1')

# %%
learn.unfreeze()

# %%
learn.lr_find()
# Out:
# LR Finder complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
#learn.fit_one_cycle(2, max_lr=slice(1e-4,1e-3))

# %%
#learn.save('stage-2')

# %% [markdown]
# learn.fit_one_cycle(1, max_lr=slice(1e-6,1e-3))

# %% [markdown]
# learn.save('stage-3')

# %% [markdown]
# **Interpreation**

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
interp.plot_confusion_matrix()

# %%
interp.plot_top_losses(2)
